# %%
# %%
import numpy as np
from matplotlib import pyplot as plt
import csv

# %matplotlib inline

import xarray as xr
import lib_ecofun as lef
from importlib import reload
reload(lef)
from scipy.optimize import curve_fit, minimize, dual_annealing, basinhopping, brute, differential_evolution, shgo, direct

# %%
reload(lef)
# Out:
# <module 'lib_ecofun' from '/home/fedef/Research/abstractsepapers/papers/DREAM/codes/lib_ecofun.py'>

# %%
gdp = lef.get_wb_gdp_data()

# %%
gdp.sel(year = 2010)
# Out:
# <xarray.DataArray ()>
# array(66707.07176466)
# Coordinates:
#     year     int64 2010

# %%
gdp.plot()

# %%
E_obs, co2 = lef.load_obs()

# %%
lef.Eg_ratio.plot()
lef.Eg_ratio_fe.plot()

# %%
lef.final_energy.sel(year = 2000)
# Out:
# <xarray.DataArray ()>
# array(2933)
# Coordinates:
#     year     int64 2000

# %%
lef.final_energy.plot()

# %%
278*2000
# Out:
# 556000

# %%
lef.primary_energy.plot()
lef.primary_energy_decomp.total.plot()

# %%
len(lef.solar_pe)
# Out:
# 41

# %%
lef.primary_energy_decomp.Solar
# Out:
# <xarray.DataArray 'Solar' (year: 77)>
# array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 8.3333330e-03,
#        1.7530864e-02, 3.2631874e-02, 4.2177327e-02, 2.9452860e-02,
#        2.8322108e-02, 7.2839785e-01, 1.0784721e+00, 1.4033967e+00,
#        1.2960530e+00, 1.5463264e+00, 1.6582857e+00, 1.7746743e+00,
#        1.9423053e+00, 2.0823772e+00, 2.2551444e+00, 2.5146885e+00,
# ...

# %%
(lef.primary_energy_decomp.total-lef.primary_energy).plot()

# %%
'{:6.2e}'.format(1e18/(1000*60*60))
# Out:
# '2.78e+11'
