# %%
# %%
import numpy as np
from matplotlib import pyplot as plt
import csv

# %matplotlib inline

import xarray as xr
import lib_ecofun as lef
from importlib import reload
reload(lef)
from scipy.optimize import curve_fit, minimize, dual_annealing, basinhopping, brute, differential_evolution, shgo, direct

# %%
reload(lef)

# %%
gdp = lef.get_wb_gdp_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gdp = lef.get_wb_gdp_data()
#
# File ~/Research/git/ecodyn/lib_ecofun.py:135, in get_wb_gdp_data(datadir)
#     134 def get_wb_gdp_data(datadir = datadir): # 2024: 173 trillions USD (our world in data)
# --> 135     with open(datadir + 'API_NY.GDP.MKTP.CD_DS2_en_csv_v2_6298258.csv', newline='') as csvfile:
#     136         reader = csv.reader(csvfile)
#     138         rows = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/fabiano/Research/git/ecodyn/../data/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_6298258.csv'
