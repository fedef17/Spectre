# %%
import numpy as np
from matplotlib import pyplot as plt
import csv

# %matplotlib inline

import lib_ecofun as lef

# %%
from importlib import reload
reload(lef)
# Out:
# <module 'lib_ecofun' from '/home/fedef/Research/abstractsepapers/papers/DREAM/codes/lib_ecofun.py'>

# %% [markdown]
# # Tuning some param

# %%
params = lef.default_params.copy()
params['beta_0'] = -0.15
# params['a'] = 0.8
params['gamma_g'] = 0.6
# params['gamma_f'] = 0.5
params['growth'] = 0.015
params['delta_g'] = 0.01
params['delta_f'] = 0.01

params['delta_sig'] = 0.5

inicond = {'Y_ini' : 1, 'Kg_ini' : lef.Eg_ratio_ok[0]/100, 'Kf_ini' : 1-lef.Eg_ratio_ok[0]/100}

n_iter = 300

# %% [markdown]
# ### growth

# %%
out = lef.calc_sens_param('growth', var_range = [0., 0.05], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ### beta_0

# %%
out = lef.calc_sens_param('beta_0', var_range = [-0.5, 0.5], n_pert = 11, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ### gamma_g

# %%
out = lef.calc_sens_param('gamma_g', var_range = [0.2, 0.8], n_pert = 7, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %%
out = lef.calc_sens_param('gamma_f', var_range = [0.2, 0.8], n_pert = 7, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %%
out = lef.calc_sens_param('a', var_range = [0.5, 1.5], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## now trying to get best match

# %%
params = lef.default_params.copy()
#params['r_inv'] = 0.2
params['delta_sig'] = 0.7
params['beta_0'] = -0.3
params['gamma_g'] = 0.5
params['growth'] = 0.015
# params['gamma_f'] = 0.5

# params['growth'] = 0.02
params['delta_g'] = 0.0
params['delta_f'] = 0.0

inicond = {'Y_ini' : 1, 'Kg_ini' : lef.Eg_ratio_ok[0]/100, 'Kf_ini' : 1-lef.Eg_ratio_ok[0]/100}

# %%
out = lef.calc_sens_param('gamma_g', var_range = [0.3, 0.7], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %%
out = lef.calc_sens_param('gamma_f', var_range = [0.3, 0.7], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %%
out = lef.calc_sens_param('growth', var_range = [0., 0.05], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %%
out = lef.calc_sens_param('delta_sig', var_range = [0.3, 0.7], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## Best model

# %%
params = lef.default_params.copy()
params['beta_0'] = -0.2
# params['a'] = 0.8
params['gamma_g'] = 0.65
params['growth'] = 0.015
params['delta_g'] = 0.0
params['delta_f'] = 0.0

params['delta_sig'] = 0.7

inicond = {'Y_ini' : 1, 'Kg_ini' : lef.Eg_ratio_ok[0]/100, 'Kf_ini' : 1-lef.Eg_ratio_ok[0]/100}

n_iter = 300

# %%
resu = lef.run_model(inicond = inicond, params = params, n_iter = n_iter, verbose = False)
lef.plot_resu(resu)
lef.plot_resuvsobs(resu)

print(2015 + resu['year_peak'], 2015 + resu['year_halved'], 2015 + resu['year_zero'])
# Out:
# 2021 2052 2061

# %%
plt.plot((resu['Pg']/resu['Kg']-resu['Pf']/resu['Kf'])/(resu['Pf']/resu['Kf']+resu['Pg']/resu['Kg']))

# %%
plt.plot(resu['Pg']/resu['Kg'])
plt.plot(resu['Pf']/resu['Kf'])
plt.plot(resu['Pg']/resu['Kg']-resu['Pf']/resu['Kf'])
plt.plot(resu['Pg']/resu['Kg']+resu['Pf']/resu['Kf'])

# %%
plt.plot(resu['Ig']/(resu['Ig']+resu['If']))
