# %%
import numpy as np
from matplotlib import pyplot as plt
import csv

# %matplotlib inline

import lib_ecofun as lef

# %%
from importlib import reload
reload(lef)
# Out:
# <module 'lib_ecofun' from '/home/fedef/Research/abstractsepapers/papers/DREAM/codes/lib_ecofun.py'>

# %% [markdown]
# # Tuning some param

# %%
params = lef.default_params.copy()
#params['r_inv'] = 0.2
# params['delta_sig'] = 0.5
# params['beta_0'] = 0
# params['gamma_g'] = 0.55
# params['gamma_f'] = 0.5

# params['growth'] = 0.02
params['delta_g'] = 0.
params['delta_f'] = 0.

inicond = {'Y_ini' : 1, 'Kg_ini' : lef.Eg_ratio_ok[0]/100, 'Kf_ini' : 1-lef.Eg_ratio_ok[0]/100}

# %% [markdown]
# ### growth

# %%
out = lef.calc_sens_param('growth', var_range = [0., 0.05], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ### beta_0

# %%
out = lef.calc_sens_param('beta_0', var_range = [-0.3, 0.3], n_pert = 7, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ### gamma_g

# %%
out = lef.calc_sens_param('gamma_g', var_range = [0.2, 0.8], n_pert = 7, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# ## now trying to get best match

# %%
params = lef.default_params.copy()
#params['r_inv'] = 0.2
# params['delta_sig'] = 0.5
params['beta_0'] = -0.2
params['gamma_g'] = 0.55
# params['gamma_f'] = 0.5

# params['growth'] = 0.02
params['delta_g'] = 0.
params['delta_f'] = 0.

inicond = {'Y_ini' : 1, 'Kg_ini' : lef.Eg_ratio_ok[0]/100, 'Kf_ini' : 1-lef.Eg_ratio_ok[0]/100}

# %%
out = lef.calc_sens_param('gamma_g', var_range = [0.3, 0.7], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [[0.01960784 0.18823529 0.38039216 1.        ]
#  [0.14248366 0.41730104 0.68335256 1.        ]
#  [0.32349097 0.61491734 0.78546713 1.        ]
#  [0.65490196 0.81437908 0.89411765 1.        ]
#  [0.88389081 0.92848904 0.95301807 1.        ]
#  [0.98200692 0.90618993 0.8615917  1.        ]
#  [0.96862745 0.71764706 0.6        1.        ]
#  [0.86228374 0.4295271  0.34271434 1.        ]
#  [0.71188005 0.12179931 0.18169935 1.        ]
#  [0.40392157 0.         0.12156863 1.        ]]
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %%
out = lef.calc_sens_param('growth', var_range = [0., 0.05], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# [[0.01960784 0.18823529 0.38039216 1.        ]
#  [0.14248366 0.41730104 0.68335256 1.        ]
#  [0.32349097 0.61491734 0.78546713 1.        ]
#  [0.65490196 0.81437908 0.89411765 1.        ]
#  [0.88389081 0.92848904 0.95301807 1.        ]
#  [0.98200692 0.90618993 0.8615917  1.        ]
#  [0.96862745 0.71764706 0.6        1.        ]
#  [0.86228374 0.4295271  0.34271434 1.        ]
#  [0.71188005 0.12179931 0.18169935 1.        ]
#  [0.40392157 0.         0.12156863 1.        ]]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)

# %%
out = lef.calc_sens_param('delta_sig', var_range = [0.3, 0.7], n_pert = 10, params = params, inicond = inicond)
lef.plot_sens_param(*out)
# Out:
# [[0.01960784 0.18823529 0.38039216 1.        ]
#  [0.14248366 0.41730104 0.68335256 1.        ]
#  [0.32349097 0.61491734 0.78546713 1.        ]
#  [0.65490196 0.81437908 0.89411765 1.        ]
#  [0.88389081 0.92848904 0.95301807 1.        ]
#  [0.98200692 0.90618993 0.8615917  1.        ]
#  [0.96862745 0.71764706 0.6        1.        ]
#  [0.86228374 0.4295271  0.34271434 1.        ]
#  [0.71188005 0.12179931 0.18169935 1.        ]
#  [0.40392157 0.         0.12156863 1.        ]]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>)
