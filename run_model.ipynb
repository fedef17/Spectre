# %%
import numpy as np
from matplotlib import pyplot as plt
import csv

# %matplotlib inline

import lib_ecofun as lef

# %%
from importlib import reload
reload(lef)
# Out:
# <module 'lib_ecofun' from '/home/fedef/Research/abstractsepapers/papers/DREAM/codes/lib_ecofun.py'>

# %%
params = lef.best_params.copy()
inicond = lef.inicond_2000
n_iter = 300

# %%
resu = lef.run_model(inicond = inicond, params = params, n_iter = n_iter, verbose = False, rule = 'maxgreen')
lef.plot_resu(resu, year_ini = 2000)
lef.plot_resuvsobs(resu, year_ini = 2000)

print(2000 + resu['year_peak'], 2000 + resu['year_halved'], 2000 + resu['year_zero'])
# Out:
# 2030 2061 2070
